# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

# %%
df=pd.read_csv("Book4.csv")
df
# Out:
#     Route No.(morning+evening)  distance  demand  capacity         cost
# 0                            6      14.2    5200      6000   992.535000
# 1                            7      20.2    5100      6000  1058.535000
# 2                            8      11.5    3250      3500   880.110000
# 3                            9      17.8    3290      3500   936.540000
# 4                           10      10.0    3200      3500   868.395000
# 5                           11       6.2    3230      3500   833.470000
# 6                           15       8.5    3220      3500   857.175000
# 7                           16      20.5    5100      6000  1056.390000
# 8                           26       6.0    3111      3500   834.680000
# 9                           27      16.6    3190      3500   926.475000
# 10                          28      27.1    5183      6000  1132.950000
# 11                          35      12.3    3000      3500   889.130000
# 12                          36      20.0    5184      6000  1053.365000
# 13                          37       7.7    5167      6000   918.560000
# 14                          43       9.7    3400      3500   867.240000
# 15                          45      11.7    3112      3500   882.365000
# 16                          46      11.5    3100      3500   879.615000
# 17                          57      14.0    3267      3500   906.565000
# 18                          58       9.0    3120      3500   860.090000
# 19                          59      10.0    2970      3500   867.405000
# 20                          60      24.7    3000      3500  1001.715000
# 21                          61      18.2    3200      3500   939.070000
# 22                          62       8.6    1530      2000   840.986667
# 23                          63      28.9    1065      2000   990.348333

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['distance','demand']],df.cost)
# Out:
# LinearRegression()

# %%
reg.predict([[14.4,5200]])
# Out:
# array([990.39051177])

# %%
#plt.scatter(df[['distance']],df.cost)
#plt.scatter(df[['demand']],df.cost)
plt.plot(df[['distance','demand']],df.cost)
plt.show()
